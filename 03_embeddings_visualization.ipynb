# %% [markdown]
# # 03 – Embeddings (OpenAI) + FAISS + PCA

# %%
from utils import parser as parser_utils
from utils import chunker as chunker_utils
from utils import embedder_openai as eo
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
df = parser_utils.load_documents('data')
chunks = chunker_utils.chunk_dataframe(df)
index, embs = eo.build_faiss_index(chunks)
pca = PCA(n_components=2).fit_transform(embs)
plt.scatter(pca[:,0], pca[:,1])
