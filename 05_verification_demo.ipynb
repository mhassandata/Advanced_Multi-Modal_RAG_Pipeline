# %% [markdown]
# # 05 – Alias Verification with OpenAI Embeddings

# %%
import pandas as pd
from utils import verify_openai as verify
df = pd.read_csv('data/alias.csv')
verify.verify_aliases(df).sort_values('score', ascending=False).head(20)
