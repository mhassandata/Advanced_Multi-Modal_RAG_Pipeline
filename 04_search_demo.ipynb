# %% [markdown]
# # 04 – Hybrid Retrieval (BM25 + OpenAI Embeddings)

# %%
from utils import parser as parser_utils
from utils import chunker as chunker_utils
from utils import retriever_openai as ro
df = parser_utils.load_documents('data')
chunks = chunker_utils.chunk_dataframe(df)
ret = ro.HybridRetriever(chunks)
ret.hybrid_search('your query here', top_k=5)
