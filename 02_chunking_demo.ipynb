# %% [markdown]
# # 02 – Chunking Heuristics

# %%
from utils import parser as parser_utils
from utils import chunker as chunker_utils
df = parser_utils.load_documents('data')
chunks = chunker_utils.chunk_dataframe(df, max_tokens=220)
chunks['tokens'] = chunks['text'].str.split().str.len()
chunks.describe()[['tokens']]
